# %%
#Import the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp

# %%
#Read the file
data=pd.read_csv("C:\\Users\\HP\\Desktop\\ML DATASETS\\EmployeeAttrition.csv")
print(data.head())
print(data.shape)
print(data.describe())
print(data.info())
print(data.columns)
print(data.dtypes)
# Out:
#    Employee Count  Employee ID              Department               Job Role  \
# 0               1            1                   Sales        Sales Executive
# 1               1            2  Research & Development     Research Scientist
# 2               1            4  Research & Development  Laboratory Technician
# 3               1            5  Research & Development     Research Scientist
# 4               1            7  Research & Development  Laboratory Technician
#
#   Attrition (Yes/No)  Gender  Age Over 18 Marital Status      Education  \
# 0                Yes  Female   41       Y         Single        College
# 1                 No    Male   49       Y        Married  Below College
# 2                Yes    Male   37       Y         Single        College
# 3                 No  Female   33       Y        Married         Master
# 4                 No    Male   27       Y        Married  Below College
#
# ...

# %%
pp.ProfileReport(data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
data.isna().sum()
# Out:
# Employee Count                0
# Employee ID                   0
# Department                    0
# Job Role                      0
# Attrition (Yes/No)            0
# Gender                        0
# Age                           0
# Over 18                       0
# Marital Status                0
# Education                     0
# Education Field               0
# Business Travel               0
# Distance From Home (kms)      0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Hourly Rate (USD)             0
# Daily Rate (USD)              0
# Monthly Rate (USD)            0
# Monthly Income (USD)          0
# Salary Hike (%)               0
# Stock Option Level            0
# Standard Hours                0
# Over Time                     0
# No. of Companies Worked       0
# Total Working Years           0
# Years At Company              0
# Years In Current Role         0
# Years Since Last Promotion    0
# ...

# %%
#rename Attrition (Yes/No) as Attrition
data.rename(columns={'Attrition (Yes/No)':'Attrition' }, inplace=True)
print(data.columns)
# Out:
# Index(['Employee Count', 'Employee ID', 'Department', 'Job Role', 'Attrition',
#        'Gender', 'Age', 'Over 18', 'Marital Status', 'Education',
#        'Education Field', 'Business Travel', 'Distance From Home (kms)',
#        'Job Involvement', 'Job Level', 'Job Satisfaction', 'Hourly Rate (USD)',
#        'Daily Rate (USD)', 'Monthly Rate (USD)', 'Monthly Income (USD)',
#        'Salary Hike (%)', 'Stock Option Level', 'Standard Hours', 'Over Time',
#        'No. of Companies Worked', 'Total Working Years', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager', 'Environment Satisfaction',
#        'Training Times Last Year', 'Work Life Balance', 'Performance Rating',
#        'Relationship Satisfaction'],
#       dtype='object')

# %%
#drop standard hours
data.drop(['Standard Hours','Employee Count','Employee ID','Over 18'], axis=1, inplace=True)
#'BusinessTravel','EducationField','Department','JobRole','MaritalStatus'

# %%
#Attrition Yes=1,Attrition No=0
# data= [1 if each == "Yes" else 0 for each in data.Attrition]

# %%
#converting categorical in to numeric
# data['Business_Travel_Rarely']=0
# data['Business_Travel_Frequently']=0
# data['Business_Non-Travel']=0

# data.loc[data['BusinessTravel']=='Travel_Rarely','Business_Travel_Rarely'] = 1
# data.loc[data['BusinessTravel']=='Travel_Frequently','Business_Travel_Frequently'] = 1
# data.loc[data['BusinessTravel']=='Non-Travel','Business_Non-Travel'] = 1
# *******************************************************
# data['Life Sciences']=0
# data['Medical']=0
# data['Marketing']=0
# data['Technical Degree']=0
# data['Education Human Resources']=0
# data['Education_Other']=0

# data.loc[data['EducationField']=='Life Sciences','Life Sciences'] = 1
# data.loc[data['EducationField']=='Medical','Medical'] = 1
# data.loc[data['EducationField']=='Other','Education_Other'] = 1
# data.loc[data['EducationField']=='Technical Degree','Technical Degree'] = 1
# data.loc[data['EducationField']=='Human Resources','Education Human Resources'] = 1
# data.loc[data['EducationField']=='Marketing','Marketing'] = 1
# *********************************************************
# data['Sales']=0
# data['R&D']=0
# data['Dept_Human Resources'] =0

# data.loc[data['Department']=='Sales','Sales'] = 1
# data.loc[data['Department']=='Research & Development','R&D'] = 1
# data.loc[data['Department']=='Human Resources','Dept_Human Resources'] = 1
# **************************************************************
# data.loc[data['Gender']=='Male','Gender'] = 1
# data.loc[data['Gender']=='Female','Gender'] = 0
# **********************************************************88
# data['Research Scientist']=0
# data['Laboratory Technician']=0
# data['Sales Executive']=0
# data['Manufacturing Director']=0
# data['Healthcare Representative']=0
# data['Sales Representative']=0
# data['Research Director']=0
# data['Manager'] = 0
# data['Job_Human_Resources'] = 0

# data.loc[data['JobRole']=='Research Scientist','Research Scientist'] = 1
# data.loc[data['JobRole']=='Laboratory Technician','Laboratory Technician'] = 1
# data.loc[data['JobRole']=='Sales Executive','Sales Executive'] = 1
# data.loc[data['JobRole']=='Sales Representative','Sales Representative'] = 1
# data.loc[data['JobRole']=='Manufacturing Director','Manufacturing Director'] = 1
# data.loc[data['JobRole']=='Healthcare Representative','Healthcare Representative'] = 1
# data.loc[data['JobRole']=='Research Director','Research Director'] = 1
# data.loc[data['JobRole']=='Manager','Manager'] = 1
# data.loc[data['JobRole']=='Human Resources','Job_Human_Resources'] = 1
# ***************************************************************
# data['Marital_single']=0
# data['Marital_married']=0
# data['Marital_divorced']=0

# data.loc[data['MaritalStatus']=='Married','Marital_married'] = 1
# data.loc[data['MaritalStatus']=='Single','Marital_single'] = 1
# data.loc[data['MaritalStatus']=='Divorced','Marital_divorced'] = 1
# *****************************************************************************888
# data.loc[data['OverTime']=='No','OverTime'] = 0
# data.loc[data['OverTime']=='Yes','OverTime'] = 1

# %%
data_dummy= pd.get_dummies(data, columns=['Attrition','Department', 'Job Role','Gender','Marital Status','Education','Education Field','Business Travel','Job Involvement','Job Satisfaction','Over Time','Environment Satisfaction','Work Life Balance','Performance Rating','Relationship Satisfaction'], drop_first=True)
data_dummy.head()
# Out:
#    Age  Distance From Home (kms)  Job Level  Hourly Rate (USD)  \
# 0   41                         1          2                 94
# 1   49                         8          2                 61
# 2   37                         2          1                 92
# 3   33                         3          1                 56
# 4   27                         2          1                 40
#
#    Daily Rate (USD)  Monthly Rate (USD)  Monthly Income (USD)  \
# 0              1102               19479                  5993
# 1               279               24907                  5130
# 2              1373                2396                  2090
# 3              1392               23159                  2909
# 4               591               16632                  3468
#
#    Salary Hike (%)  Stock Option Level  No. of Companies Worked  \
# 0               11                   0                        8
# 1               23                   1                        1
# ...

# %%
data_dummy.columns
# Out:
# Index(['Age', 'Distance From Home (kms)', 'Job Level', 'Hourly Rate (USD)',
#        'Daily Rate (USD)', 'Monthly Rate (USD)', 'Monthly Income (USD)',
#        'Salary Hike (%)', 'Stock Option Level', 'No. of Companies Worked',
#        'Total Working Years', 'Years At Company', 'Years In Current Role',
#        'Years Since Last Promotion', 'Years With Curr Manager',
#        'Training Times Last Year', 'Attrition_Yes',
#        'Department_Research & Development', 'Department_Sales',
#        'Job Role_Human Resources', 'Job Role_Laboratory Technician',
#        'Job Role_Manager', 'Job Role_Manufacturing Director',
#        'Job Role_Research Director', 'Job Role_Research Scientist',
#        'Job Role_Sales Executive', 'Job Role_Sales Representative',
#        'Gender_Male', 'Marital Status_Married', 'Marital Status_Single',
#        'Education_Below College', 'Education_College', 'Education_Doctor',
#        'Education_Master', 'Education Field_Life Sciences',
# ...

# %%
#plot correlation [plot]
fig,ax = plt.subplots(figsize=(38, 38))
sns.heatmap(data_dummy.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %%
#rename Attrition (Yes/No) as Attrition
data_dummy.rename(columns={'Attrition_Yes':'Attrition' }, inplace=True)
print(data_dummy.columns)
# Out:
# Index(['Age', 'Distance From Home (kms)', 'Job Level', 'Hourly Rate (USD)',
#        'Daily Rate (USD)', 'Monthly Rate (USD)', 'Monthly Income (USD)',
#        'Salary Hike (%)', 'Stock Option Level', 'No. of Companies Worked',
#        'Total Working Years', 'Years At Company', 'Years In Current Role',
#        'Years Since Last Promotion', 'Years With Curr Manager',
#        'Training Times Last Year', 'Attrition',
#        'Department_Research & Development', 'Department_Sales',
#        'Job Role_Human Resources', 'Job Role_Laboratory Technician',
#        'Job Role_Manager', 'Job Role_Manufacturing Director',
#        'Job Role_Research Director', 'Job Role_Research Scientist',
#        'Job Role_Sales Executive', 'Job Role_Sales Representative',
#        'Gender_Male', 'Marital Status_Married', 'Marital Status_Single',
#        'Education_Below College', 'Education_College', 'Education_Doctor',
#        'Education_Master', 'Education Field_Life Sciences',
# ...

# %%
data_dummy["Attrition"].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(data_dummy["Attrition"],label='count')

# %%
y=data_dummy['Attrition']
X=data_dummy.drop(columns="Attrition")

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
# split data train 70 % and test 30 %
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
 ######################generalisation on imbalanced data Random Forest Logistic Regression  *************************

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier(random_state=123)
rf_clf.fit(X_train,y_train)
y_pred_test_R=rf_clf.predict(X_test)
y_pred_train_R=rf_clf.predict(X_train)

# %%
print(accuracy_score(y_pred_test_R,y_test))
print(confusion_matrix(y_pred_test_R,y_test))
print(classification_report(y_pred_test_R,y_test))
# Out:
# 0.8594104308390023
# [[371  53]
#  [  9   8]]
#              precision    recall  f1-score   support
#
#           0       0.98      0.88      0.92       424
#           1       0.13      0.47      0.21        17
#
# avg / total       0.94      0.86      0.90       441

# %%
print(accuracy_score(y_pred_train_R,y_train))
print(confusion_matrix(y_pred_train_R,y_train))
print(classification_report(y_pred_train_R,y_train))
# Out:
# 0.9757045675413022
# [[853  25]
#  [  0 151]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.97      0.99       878
#           1       0.86      1.00      0.92       151
#
# avg / total       0.98      0.98      0.98      1029

# %%
###################### end of random forest #################################

# %%
#Randomforest
#importing modules
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
#making the instance
model=RandomForestClassifier()
#hyper parameters set
params = {'criterion':['gini','entropy'],
          'max_features': ['auto', 'sqrt', 'log2'],
          'n_estimators':[10,15,20,25,30],
          'min_samples_leaf':[1,2,3],
          'min_samples_split':[3,4,5,6,7], 
          'random_state':[123],
          'bootstrap': [True,False],
          'random_state':[126],
          'n_jobs':[-1]}
#Making models with hyper parameters sets
model1 = GridSearchCV(model, param_grid=params, n_jobs=-1)
#learning
model1.fit(X_train,y_train)
#The best hyper parameters set
print("Best Hyper Parameters:\n",model1.best_params_)
#Prediction
prediction=model1.predict(X_test)
#evaluation(Accuracy)
print("Accuracy:",accuracy_score(prediction,y_test))
#evaluation(Confusion Metrix)
print("Confusion Metrix:\n",confusion_matrix(prediction,y_test))
print(classification_report(prediction,y_test))
# Out:
# Best Hyper Parameters:
#  {'bootstrap': True, 'criterion': 'entropy', 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 15, 'n_jobs': -1, 'random_state': 126}
# Accuracy: 0.8594104308390023
# Confusion Metrix:
#  [[376  58]
#  [  4   3]]
#              precision    recall  f1-score   support
#
#           0       0.99      0.87      0.92       434
#           1       0.05      0.43      0.09         7
#
# avg / total       0.97      0.86      0.91       441

# %%
#train data
prediction1=model1.predict(X_train)
print("Accuracy:",accuracy_score(prediction1,y_train))
#evaluation(Confusion Metrix)
print("Confusion Metrix:\n",confusion_matrix(prediction1,y_train))
print(classification_report(prediction1,y_train))
# Out:
# Accuracy: 0.9494655004859086
# Confusion Metrix:
#  [[853  52]
#  [  0 124]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.94      0.97       905
#           1       0.70      1.00      0.83       124
#
# avg / total       0.96      0.95      0.95      1029

# %%
##############################3 end of random forest hyper parameter tuning $$$$$$$$$$$$$$$$$$$$

# %%
 ######################generalisation on imbalanced data using Logistic Regression  *************************

# %%
from sklearn.linear_model import LogisticRegression
lg_reg=LogisticRegression()
lg_reg.fit(X_train,y_train)
y_pred_train_G=lg_reg.predict(X_train)
y_pred_test_G=lg_reg.predict(X_test)

# %%
print(accuracy_score(y_pred_test_G,y_test))
print(confusion_matrix(y_pred_test_G,y_test))
print(classification_report(y_pred_test_G,y_test))
# Out:
# 0.8684807256235828
# [[366  44]
#  [ 14  17]]
#              precision    recall  f1-score   support
#
#           0       0.96      0.89      0.93       410
#           1       0.28      0.55      0.37        31
#
# avg / total       0.92      0.87      0.89       441

# %%
print(accuracy_score(y_pred_train_G,y_train))
print(confusion_matrix(y_pred_train_G,y_train))
print(classification_report(y_pred_train_G,y_train))
# Out:
# 0.8824101068999028
# [[839 107]
#  [ 14  69]]
#              precision    recall  f1-score   support
#
#           0       0.98      0.89      0.93       946
#           1       0.39      0.83      0.53        83
#
# avg / total       0.94      0.88      0.90      1029

# %%
print("ACCURACY {}:". format(((839+69)/(839+69+107+14))*100))
# Out:
# ACCURACY 88.24101068999029:

# %%
####################### end of generalisation on imbalanced data *****************************

# %%
#################### Recursive Feature Elimination #######################

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
# The "accuracy" scoring is proportional to the number of correct classifications
clf_rf_4 = LogisticRegression()
clf_rf_5=  RandomForestClassifier()

rfecv = RFECV(estimator=clf_rf_4, step=1, cv=5,scoring='accuracy')   #5-fold cross-validation
rfecv = rfecv.fit(X_train, y_train)

print('Optimal number of features :', rfecv.n_features_)
print('Best features :', X_train.columns[rfecv.support_])
# Out:
# Optimal number of features : 51
# Best features : Index(['Age', 'Distance From Home (kms)', 'Job Level', 'Stock Option Level',
#        'No. of Companies Worked', 'Total Working Years', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager', 'Training Times Last Year',
#        'Department_Research & Development', 'Department_Sales',
#        'Job Role_Human Resources', 'Job Role_Laboratory Technician',
#        'Job Role_Manager', 'Job Role_Manufacturing Director',
#        'Job Role_Research Director', 'Job Role_Research Scientist',
#        'Job Role_Sales Executive', 'Job Role_Sales Representative',
#        'Gender_Male', 'Marital Status_Married', 'Marital Status_Single',
#        'Education_Below College', 'Education_College', 'Education_Doctor',
#        'Education Field_Life Sciences', 'Education Field_Marketing',
#        'Education Field_Medical', 'Education Field_Other',
# ...

# %%
#Create estimator class
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import  GridSearchCV
estimator = LogisticRegression()

#Create param grid
paramgrid = {'C': [0.001,0.005,0.01, 0.05, 0.1, 0.5, 1, 5, 10], 'penalty': ['l1','l2'],'random_state':[125]}

#Create SearchGridCV optimizer
optimizer = GridSearchCV(estimator, paramgrid, cv=10)
#Fit it for original data
optimizer.fit(X_train, y_train)
y_pred_test_1 = optimizer.best_estimator_.predict(X_test)
y_pred_train_1=optimizer.best_estimator_.predict(X_train)
print(optimizer.best_estimator_)
# Out:
# LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=125, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,classification_report,auc
print(accuracy_score(y_pred_test_1,y_test))
print(confusion_matrix(y_pred_test_1,y_test))
print(classification_report(y_pred_test_1,y_test))
# Out:
# 0.854875283446712
# [[351  35]
#  [ 29  26]]
#              precision    recall  f1-score   support
#
#           0       0.92      0.91      0.92       386
#           1       0.43      0.47      0.45        55
#
# avg / total       0.86      0.85      0.86       441

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,classification_report,auc
print(accuracy_score(y_pred_train_1,y_train))
print(confusion_matrix(y_pred_train_1,y_train))
print(classification_report(y_pred_train_1,y_train))
# Out:
# 0.8999028182701652
# [[830  80]
#  [ 23  96]]
#              precision    recall  f1-score   support
#
#           0       0.97      0.91      0.94       910
#           1       0.55      0.81      0.65       119
#
# avg / total       0.92      0.90      0.91      1029

# %%
####################3 end of RFECV ********************************************88

# %%
#################  hyper parameter tuning on imbalanced data  ********************

# %%
#Create estimator class
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import  GridSearchCV
estimator = LogisticRegression()

#Create param grid
paramgrid = {'C': [0.0001,0.005,0.001,0.005,0.01, 0.05, 0.1, 0.5, 1, 5, 10,50,90,100], 'penalty': ['l1','l2'],'random_state':[125]}

#Create SearchGridCV optimizer
optimizer = GridSearchCV(estimator, paramgrid, cv=10)
#Fit it for original data
optimizer.fit(X_train, y_train)
y_pred = optimizer.best_estimator_.predict(X_test)
print(optimizer.best_estimator_)
# Out:
# LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=125, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_train=optimizer.best_estimator_.predict(X_train)
print(accuracy_score(y_pred_train_G,y_train))
print(confusion_matrix(y_pred_train_G,y_train))
print(classification_report(y_pred_train_G,y_train))
# Out:
# 0.8824101068999028
# [[839 107]
#  [ 14  69]]
#              precision    recall  f1-score   support
#
#           0       0.98      0.89      0.93       946
#           1       0.39      0.83      0.53        83
#
# avg / total       0.94      0.88      0.90      1029

# %%
print("ACCURACY {}:". format(((839+69)/(839+69+107+14))*100))
# Out:
# ACCURACY 88.24101068999029:

# %%
print(accuracy_score(y_pred_test_G,y_test))
print(confusion_matrix(y_pred_test_G,y_test))
print(classification_report(y_pred_test_G,y_test))
# Out:
# 0.8684807256235828
# [[366  44]
#  [ 14  17]]
#              precision    recall  f1-score   support
#
#           0       0.96      0.89      0.93       410
#           1       0.28      0.55      0.37        31
#
# avg / total       0.92      0.87      0.89       441

# %%
print("ACCURACY {}:". format(((366+17)/(366+17+44+14))*100))
# Out:
# ACCURACY 86.84807256235828:

# %%
#################   end of hyper parameter tuning on imbalanced data  ********************

# %%
############convert imbalanced data in to balanced data*********************************8

# %%
#upsampling
from sklearn.utils import resample
# Separate majority and minority classes
df_majority = data_dummy[data_dummy.Attrition==0]
df_minority = data_dummy[data_dummy.Attrition==1]
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=1233,    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# %%
y=df_upsampled['Attrition']
X=df_upsampled.drop(columns="Attrition")

# %%
y.value_counts()
# Out:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %%
#attrition
sns.countplot(y,label='count')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
# split data train 70 % and test 30 %
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#select best features
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# find best scored 5 features
select_feature = SelectKBest(chi2, k=5).fit(X_train, y_train)
print('Score list:', select_feature.scores_)
print('Feature list:', X_train.columns)
# Out:
# Score list: [1.83285127e+02 9.12318802e+01 4.88955082e+01 2.13675925e+00
#  2.87759192e+03 8.95366771e+03 2.47882816e+05 1.24518706e-02
#  6.36883244e+01 1.89922588e+01 5.49395464e+02 2.91361691e+02
#  2.54197607e+02 3.55186759e+01 3.19428306e+02 2.61249723e+00
#  6.81782221e+00 1.09672923e+01 2.61361168e+00 2.49249640e+01
#  1.81887948e+01 3.20648872e+01 3.49479994e+01 2.99655197e-02
#  7.35493658e-02 4.44584722e+01 2.31628719e-01 2.49681530e+01
#  6.62439221e+01 3.51836538e-01 1.80164904e+00 3.22399836e+00
#  1.34033608e+00 1.05359640e+00 7.55357675e+00 5.03641368e+00
#  3.64338029e+00 1.31360535e+01 2.74814160e+01 2.40074456e+00
#  2.92920998e+01 6.38138461e+00 7.28275284e+00 1.66416120e+01
#  5.29261662e-02 1.38712231e+01 1.01718851e+02 2.99971926e+01
#  2.60573205e-02 7.16032935e+00 1.73588000e-01 1.80829154e+00
#  2.20106498e-01 6.32082330e-01 1.16227190e+01 5.67447678e-01
#  1.22860318e+00]
# ...

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
# Create the RFE object and rank each pixel
clf_rf_3 = RandomForestClassifier()      
rfe = RFE(estimator=clf_rf_3, n_features_to_select=15, step=1)
rfe = rfe.fit(X_train, y_train)
print('Chosen best 5 feature by rfe:',X_train.columns[rfe.support_])
# Out:
# Chosen best 5 feature by rfe: Index(['Age', 'Distance From Home (kms)', 'Job Level', 'Hourly Rate (USD)',
#        'Daily Rate (USD)', 'Monthly Rate (USD)', 'Monthly Income (USD)',
#        'Salary Hike (%)', 'Stock Option Level', 'No. of Companies Worked',
#        'Total Working Years', 'Years At Company', 'Years With Curr Manager',
#        'Training Times Last Year', 'Over Time_Yes'],
#       dtype='object')

# %%
####################################hyper parameter tuning#########################################33
######################################Logistic Regression#############################################3

# %%
#Create estimator class
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import  GridSearchCV
estimator = LogisticRegression()

#Create param grid
paramgrid = {'C': [0.0001,0.005,0.001,0.005,0.01, 0.05, 0.1, 0.5, 1, 5, 10,50,90,100], 'penalty': ['l1','l2'],'random_state':[125]}

#Create SearchGridCV optimizer
optimizer = GridSearchCV(estimator, paramgrid, cv=10)
#Fit it for original data
optimizer.fit(X_train, y_train)
y_pred = optimizer.best_estimator_.predict(X_test)
print(optimizer.best_estimator_)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=125, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred_train=optimizer.best_estimator_.predict(X_train)
print(accuracy_score(y_pred_train,y_train))
print(confusion_matrix(y_pred_train,y_train))
print(classification_report(y_pred_train,y_train))
# Out:
# 0.7920046349942063
# [[679 172]
#  [187 688]]
#              precision    recall  f1-score   support
#
#           0       0.78      0.80      0.79       851
#           1       0.80      0.79      0.79       875
#
# avg / total       0.79      0.79      0.79      1726

# %%
print(accuracy_score(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# 0.8027027027027027
# [[295  74]
#  [ 72 299]]
#              precision    recall  f1-score   support
#
#           0       0.80      0.80      0.80       369
#           1       0.80      0.81      0.80       371
#
# avg / total       0.80      0.80      0.80       740

# %%
y_pred_prob= optimizer.best_estimator_.predict_proba(X_test)

# %%
#roc curve
from sklearn.metrics import roc_auc_score,roc_curve,auc
fpr, tpr, thresholds = roc_curve(y_test,y_pred)

# %%
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)
# Out:
# Area under the ROC curve : 0.802712

# %%
plt.plot(fpr,tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Heart disease classifier')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

# %%
##################################General Method###################################

# %%
from sklearn.linear_model import LogisticRegression
lg_reg=LogisticRegression()
lg_reg.fit(X_train,y_train)
y_pred_train=lg_reg.predict(X_train)
y_pred_test=lg_reg.predict(X_test)

# %%
print(accuracy_score(y_pred_test,y_test))
print(confusion_matrix(y_pred_test,y_test))
print(classification_report(y_pred_test,y_test))
# Out:
# 0.8
# [[293  74]
#  [ 74 299]]
#              precision    recall  f1-score   support
#
#           0       0.80      0.80      0.80       367
#           1       0.80      0.80      0.80       373
#
# avg / total       0.80      0.80      0.80       740

# %%
print(accuracy_score(y_pred_train,y_train))
print(confusion_matrix(y_pred_train,y_train))
print(classification_report(y_pred_train,y_train))
# Out:
# 0.7914252607184241
# [[678 172]
#  [188 688]]
#              precision    recall  f1-score   support
#
#           0       0.78      0.80      0.79       850
#           1       0.80      0.79      0.79       876
#
# avg / total       0.79      0.79      0.79      1726

# %%
#############################################################################

# %% [markdown]
# # conclusions#####################

# %% [markdown]
# For Imbalanced data:
#
#                     Hyper parameter tuning(with out)                With                        REcursive feature elimination
#
#                     Train           Test                      Train      test               train         test
#
#
#     Accuracy         88            87                      88.2       86.84                  89.9        85.48
#
#     precision        0.94          0.92                    0.94        0.92                  0.92        0.86
#
#     Recall           0.88         0.87                     0.88        0.87                  0.90         0.85
#
#     F1_score         0.90         0.89                     0.90         0.89                 0.91        0.86

# %% [markdown]
# For balanced data:
#
#                     Hyper parameter tuning(with out)                With
#
#                     Train           Test                      Train      test
#
#
#     Accuracy         0.79           0.80                      0.79       0.80
#
#     precision        0.79           0.80                    0.79        0.80
#
#     Recall           0.79           0.80                    0.79       0.8
#
#     F1_score         0.79           0.80                    0.79        0.8

# %% [markdown]
# Random forest generalisation :
# Test data:
# -------------
# 0.8594104308390023
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.88      0.92       424
#
#           1       0.13      0.47      0.21        17
#
#
# avg / total       0.94      0.86      0.90       441
#
# train data:
# -------------
# 0.9757045675413022
#
#              precision    recall  f1-score   support
#
#           0       1.00      0.97      0.99       878
#
#           1       0.86      1.00      0.92       151
#
#
# avg / total       0.98      0.98      0.98      1029
#
#
# Random Forest hypr tuning:
#
# test data
# -----------
#
# Accuracy: 0.8594104308390023
#
#              precision    recall  f1-score   support
#
#           0       0.99      0.87      0.92       434
#
#           1       0.05      0.43      0.09         7
#
#
# avg / total       0.97      0.86      0.91       441
#
#
#
# Train data
# -------------
# Accuracy: 0.9494655004859086
#
#              precision    recall  f1-score   support
#
#           0       1.00      0.94      0.97       905
#
#           1       0.70      1.00      0.83       124
#
#
# avg / total       0.96      0.95      0.95      1029
