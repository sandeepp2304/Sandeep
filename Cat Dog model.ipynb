# %%
# Part 1 - Building the CNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D,ZeroPadding2D,Dropout
from keras.layers import Flatten
from keras.layers import Dense

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c32a6cee2f13> in <module>
#       1 # Compiling the CNN
# ----> 2 model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
#
# NameError: name 'model' is not defined

# %%
import cv2
cascade_file_src = "haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascade_file_src)

# %%
# load image on gray scale :
image = cv2.imread("C:\\Users\\HP\\Desktop\\PHOTOS\\PHOTO SANDEEP ORIGINAL.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)

# %%
# detect faces in the image :
faces = faceCascade.detectMultiScale(gray, 1.3, 5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-4988580086e9> in <module>
#       1 # detect faces in the image :
# ----> 2 faces = faceCascade.detectMultiScale(gray, 1.3, 5)
#
# error: OpenCV(4.0.0) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1658: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %%
# draw rectangles around the faces :
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.imshow(image)
